# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import glob
import os

# %matplotlib inline

# %%
file = os.path.join('C:\\Users\\saras\\Documents\\NSS\\Capstone\\final_capstone\\Data\\', 'tornado_*.csv')
file = glob.glob(file)
tornado_years = pd.concat(map(pd.read_csv,file), ignore_index = True)
tornado_years
# Out:
#        EVENT_ID     CZ_NAME_STR BEGIN_LOCATION BEGIN_DATE BEGIN_TIME  \
# 0      10063615   ST. LOUIS CO.                  1/3/1950       1100
# 1      10009710     MADISON CO.                  1/3/1950       1110
# 2      10009711  MONTGOMERY CO.                  1/3/1950       1155
# 3      10086808    VAN WERT CO.                  1/3/1950       1600
# 4       9981922        POLK CO.                 1/13/1950        525
# ...         ...             ...            ...        ...        ...
# 35238    955453       LOGAN CO.       STERLING  5/23/2021       1449
# 35239    952078     PERKINS CO.           USTA  5/23/2021       1450
# 35240    952080      CUSTER CO.        PRINGLE  5/23/2021       1455
# 35241    952079     PERKINS CO.         MEADOW  5/23/2021       1458
# 35242    952081      CUSTER CO.         CUSTER  5/23/2021       1504
#
#       EVENT_TYPE MAGNITUDE TOR_F_SCALE DEATHS_DIRECT  INJURIES_DIRECT  ...  \
# 0        Tornado         0          F3             0                3  ...
# 1        Tornado         0          F3             0                0  ...
# 2        Tornado         0          F3             0                3  ...
# 3        Tornado         0          F1             0                1  ...
# 4        Tornado         0          F3             1                1  ...
# ...          ...       ...         ...           ...              ...  ...
# 35238    Tornado                   EF1             0                0  ...
# 35239    Tornado                   EFU             0                0  ...
# 35240    Tornado                   EF1             0                0  ...
# 35241    Tornado                   EFU             0                0  ...
# 35242    Tornado                   EF1             0                0  ...
#
#        Unnamed: 47  Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51  \
# 0              NaN          NaN         NaN         NaN         NaN
# 1              NaN          NaN         NaN         NaN         NaN
# 2              NaN          NaN         NaN         NaN         NaN
# 3              NaN          NaN         NaN         NaN         NaN
# 4              NaN          NaN         NaN         NaN         NaN
# ...            ...          ...         ...         ...         ...
# 35238          NaN          NaN         NaN         NaN         NaN
# 35239          NaN          NaN         NaN         NaN         NaN
# 35240          NaN          NaN         NaN         NaN         NaN
# 35241          NaN          NaN         NaN         NaN         NaN
# 35242          NaN          NaN         NaN         NaN         NaN
#
#       Unnamed: 52 Unnamed: 53 Unnamed: 54 Unnamed: 55 Unnamed: 56
# 0             NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...
# 35238         NaN         NaN         NaN         NaN         NaN
# 35239         NaN         NaN         NaN         NaN         NaN
# 35240         NaN         NaN         NaN         NaN         NaN
# 35241         NaN         NaN         NaN         NaN         NaN
# 35242         NaN         NaN         NaN         NaN         NaN
#
# [35243 rows x 57 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
tornado_years = tornado_years.drop(tornado_years.columns[38:],axis=1)

# %%
tornado_years
# Out:
#        EVENT_ID     CZ_NAME_STR BEGIN_LOCATION BEGIN_DATE BEGIN_TIME  \
# 0      10063615   ST. LOUIS CO.                  1/3/1950       1100
# 1      10009710     MADISON CO.                  1/3/1950       1110
# 2      10009711  MONTGOMERY CO.                  1/3/1950       1155
# 3      10086808    VAN WERT CO.                  1/3/1950       1600
# 4       9981922        POLK CO.                 1/13/1950        525
# ...         ...             ...            ...        ...        ...
# 35238    955453       LOGAN CO.       STERLING  5/23/2021       1449
# 35239    952078     PERKINS CO.           USTA  5/23/2021       1450
# 35240    952080      CUSTER CO.        PRINGLE  5/23/2021       1455
# 35241    952079     PERKINS CO.         MEADOW  5/23/2021       1458
# 35242    952081      CUSTER CO.         CUSTER  5/23/2021       1504
#
#       EVENT_TYPE MAGNITUDE TOR_F_SCALE DEATHS_DIRECT  INJURIES_DIRECT  \
# 0        Tornado         0          F3             0                3
# 1        Tornado         0          F3             0                0
# 2        Tornado         0          F3             0                3
# 3        Tornado         0          F1             0                1
# 4        Tornado         0          F3             1                1
# ...          ...       ...         ...           ...              ...
# 35238    Tornado                   EF1             0                0
# 35239    Tornado                   EFU             0                0
# 35240    Tornado                   EF1             0                0
# 35241    Tornado                   EFU             0                0
# 35242    Tornado                   EF1             0                0
#
#        DAMAGE_PROPERTY_NUM  DAMAGE_CROPS_NUM STATE_ABBR CZ_TIMEZONE  \
# 0                2500000.0                 0         MO         CST
# 1                 250000.0                 0         IL         CST
# 2                 250000.0                 0         IL         CST
# 3                  25000.0                 0         OH         CST
# 4                   2500.0                 0         AR         CST
# ...                    ...               ...        ...         ...
# 35238                  0.0                 0         CO       MST-7
# 35239                  0.0                 0         SD       MST-7
# 35240                  0.0                 0         SD       MST-7
# 35241                  0.0                 0         SD       MST-7
# 35242                  0.0                 0         SD       MST-7
#
#       MAGNITUDE_TYPE EPISODE_ID CZ_TYPE CZ_FIPS  WFO INJURIES_INDIRECT  \
# 0                                     C     189                      0
# 1                                     C     119                      0
# 2                                     C     135                      0
# 3                                     C     161                      0
# 4                                     C     113                      0
# ...              ...        ...     ...     ...  ...               ...
# 35238                    158058       C      75  BOU                 0
# 35239                    157459       C     105  UNR                 0
# 35240                    157460       C      33  UNR                 0
# 35241                    157459       C     105  UNR                 0
# 35242                    157460       C      33  UNR                 0
#
#        DEATHS_INDIRECT            SOURCE FLOOD_CAUSE TOR_LENGTH TOR_WIDTH  \
# 0                    0                                      6.2       150
# 1                    0                                      3.3       100
# 2                    0                                      3.6       130
# 3                    0                                      0.1        33
# 4                    0                                      0.6        17
# ...                ...               ...         ...        ...       ...
# 35238                0   County Official                    0.1        50
# 35239                0      Storm Chaser                   2.13        10
# 35240                0  NWS Storm Survey                    6.6        20
# 35241                0      Storm Chaser                   4.26        10
# 35242                0  NWS Storm Survey                   5.86        10
#
#       BEGIN_RANGE BEGIN_AZIMUTH END_RANGE END_AZIMUTH END_LOCATION   END_DATE  \
# 0               0                       0                            1/3/1950
# 1               0                       0                            1/3/1950
# 2               0                       0                            1/3/1950
# 3               0                       0                            1/3/1950
# 4               0                       0                           1/13/1950
# ...           ...           ...       ...         ...          ...        ...
# 35238           3           ESE         3         ESE     STERLING  5/23/2021
# 35239           6           NNW         8         NNW         USTA  5/23/2021
# 35240           4             N         5         ESE       CUSTER  5/23/2021
# 35241          10             S         6           S       MEADOW  5/23/2021
# 35242           1            NE         7         ENE       CUSTER  5/23/2021
#
#       END_TIME BEGIN_LAT BEGIN_LON END_LAT END_LON  \
# 0         1100     38.77    -90.22   38.82  -90.12
# 1         1110     38.82     -90.1   38.83  -90.03
# 2         1155      39.1     -89.3   39.12  -89.23
# 3         1600     40.88    -84.58
# 4          525      34.4    -94.37
# ...        ...       ...       ...     ...     ...
# 35238     1500     40.61   -103.14   40.61 -103.14
# 35239     1455      45.3   -102.19   45.33  -102.2
# 35240     1505     43.67    -103.6   43.74 -103.51
# 35241     1505     45.38   -102.22   45.44 -102.24
# 35242     1513     43.78   -103.58   43.81 -103.47
#
#                                          EVENT_NARRATIVE  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 35238  A tornado touched down and knocked power poles...
# 35239  A tornado formed west of SD Highway 73, about ...
# 35240  A tornado was reported about five miles south ...
# 35241  A tornado formed shortly after a previous torn...
# 35242  A tornado touched down just northeast of Custe...
#
#                                        EPISODE_NARRATIVE
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 35238  Severe thunderstorms developed across Lincoln,...
# 35239  A supercell thunderstorm tracked northward acr...
# 35240  A line of severe thunderstorms developed over ...
# 35241  A supercell thunderstorm tracked northward acr...
# 35242  A line of severe thunderstorms developed over ...
#
# [35243 rows x 38 columns]
